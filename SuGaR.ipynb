# %% [markdown]
# <a href="https://colab.research.google.com/github/pushkar-hue/3DGS/blob/master/SuGaR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install colmap
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [101 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,840 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,118 kB]
# ...

# %%
# !colmap help
# Out:
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
# Available commands:
#   help
#   gui
#   automatic_reconstructor
#   bundle_adjuster
#   color_extractor
#   database_cleaner
#   database_creator
#   database_merger
#   delaunay_mesher
#   exhaustive_matcher
#   feature_extractor
#   feature_importer
#   hierarchical_mapper
#   image_deleter
#   image_filterer
#   image_rectifier
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !unzip /content/images.zip
# Out:
# Archive:  /content/images.zip
#    creating: images/
#   inflating: images/frame_0001.png
#   inflating: images/frame_0002.png
#   inflating: images/frame_0003.png
#   inflating: images/frame_0004.png
#   inflating: images/frame_0005.png
#   inflating: images/frame_0006.png
#   inflating: images/frame_0007.png
#   inflating: images/frame_0008.png
#   inflating: images/frame_0009.png
#   inflating: images/frame_0010.png
#   inflating: images/frame_0011.png
#   inflating: images/frame_0012.png
#   inflating: images/frame_0013.png
#   inflating: images/frame_0014.png
#   inflating: images/frame_0015.png
#   inflating: images/frame_0016.png
#   inflating: images/frame_0017.png
#   inflating: images/frame_0018.png
#   inflating: images/frame_0019.png
#   inflating: images/frame_0020.png
#   inflating: images/frame_0021.png
#   inflating: images/frame_0022.png
#   inflating: images/frame_0023.png
#   inflating: images/frame_0024.png
#   inflating: images/frame_0025.png
# ...

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (346/346), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/gaussian-splatting/submodules/simple-knn
# Out:
# /content/gaussian-splatting
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for simple_knn
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (simple_knn)

# %%
# %cd /content/gaussian-splatting/submodules/simple-knn

# Inject the missing C++ header at the top of the CUDA file
# !sed -i '1s/^/#include <cfloat>\n/' simple_knn.cu

# Navigate back and try the install again
# %cd /content/gaussian-splatting
# !pip install -v --no-build-isolation ./submodules/simple-knn
# Out:
# /content/gaussian-splatting/submodules/simple-knn
# /content/gaussian-splatting
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing ./submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info
#   writing /tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info/SOURCES.txt'
#   W0719 14:18:09.793000 3654 torch/utils/cpp_extension.py:680] Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   reading manifest file '/tmp/pip-pip-egg-info-ix0u4vfs/simple_knn.egg-info/SOURCES.txt'
# ...

# %%
# !mv /content/images /content/input

# %%
# %cd /content/gaussian-splatting
# !python convert.py -s /content --no_gpu
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ...
# Registering image #88 (70)
# ...
#
#   => Image sees 282 / 459 points
#
# Pose refinement report
# ----------------------
#     Residuals : 636
#    Parameters : 6
#    Iterations : 14
#          Time : 0.00985193 [s]
#  Initial cost : 0.763187 [px]
#    Final cost : 0.649966 [px]
#   Termination : Convergence
#
#   => Continued observations: 276
#   => Added observations: 131
#
# Bundle adjustment report
# ------------------------
#     Residuals : 5902
#    Parameters : 1130
#    Iterations : 16
#          Time : 0.12019 [s]
#  Initial cost : 0.636392 [px]
#    Final cost : 0.622127 [px]
#   Termination : Convergence
#
#   => Merged observations: 85
#   => Completed observations: 21
#   => Filtered observations: 50
#   => Changed observations: 0.047970
#
# Bundle adjustment report
# ------------------------
#     Residuals : 5814
#    Parameters : 1112
#    Iterations : 3
#          Time : 0.022342 [s]
# ...

# %%
# %cd /content/gaussian-splatting
# !python train.py -s /content
# Out:
# /content/gaussian-splatting
# 2026-07-19 14:59:38.340933: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimizing
# Output folder: ./output/2442f69b-5 [19/07 14:59:43]
# Reading camera 146/146 [19/07 14:59:43]
# Converting point3d.bin to .ply, will happen only the first time you open the scene. [19/07 14:59:43]
# Loading Training Cameras [19/07 14:59:43]
# Loading Test Cameras [19/07 15:00:02]
# Number of points at initialisation :  8746 [19/07 15:00:02]
# Training progress:  13% 4030/30000 [07:35<50:25,  8.58it/s, Loss=0.0224440]Traceback (most recent call last):
#   File "/content/gaussian-splatting/train.py", line 216, in <module>
# ...

# %%
# HTTPS
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/Anttwo/SuGaR.git --recursive
# Out:
# Cloning into 'SuGaR'...
# remote: Enumerating objects: 2490, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 2490 (delta 109), reused 107 (delta 107), pack-reused 2262 (from 1)
# Receiving objects: 100% (2490/2490), 98.08 MiB | 14.95 MiB/s, done.
# Resolving deltas: 100% (1203/1203), done.

# %%
# %cd /content/SuGaR/
# !python install.py
# Out:
# /content/SuGaR
# [INFO] Creating the conda environment for SuGaR...
# sh: 1: conda: not found
# [INFO] Conda environment created.
# [INFO] Installing the 3D Gaussian Splatting rasterizer...
# sh: 1: conda: not found
# [INFO] 3D Gaussian Splatting rasterizer installed.
# [INFO] Installing simple-knn...
# sh: 1: conda: not found
# [INFO] simple-knn installed.
# [INFO] Installing Nvdiffrast...
# Cloning into 'nvdiffrast'...
# remote: Enumerating objects: 523, done.
# remote: Counting objects: 100% (265/265), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 523 (delta 198), reused 190 (delta 190), pack-reused 258 (from 1)
# Receiving objects: 100% (523/523), 11.12 MiB | 13.39 MiB/s, done.
# Resolving deltas: 100% (284/284), done.
# sh: 1: conda: not found
# [INFO] Nvdiffrast installed.
# [INFO] Please note that Nvdiffrast will take a few seconds or minutes to build the first time it is used.
# [INFO] SuGaR installation complete.

# %%
# !pip install open3d plyfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 117.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 98.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 121.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
# %cd /content/SuGaR/gaussian_splatting/submodules/diff-gaussian-rasterization
# !pip install .

# %cd /content/SuGaR/gaussian_splatting/submodules/simple-knn
# !pip install .
# Out:
# /content/SuGaR/gaussian_splatting/submodules/diff-gaussian-rasterization
# Processing /content/SuGaR/gaussian_splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3802634 sha256=1c6d05784f0664b09c09495a68aa0361d2c48da83ad2fb45cef428c4f0cacc64
#   Stored in directory: /root/.cache/pip/wheels/1c/e9/bf/f5bef4fa1017e061ad7d2993dfee1e81f12fb7193422ea464e
# Successfully built diff_gaussian_rasterization
# ...
#   Attempting uninstall: diff_gaussian_rasterization
#     Found existing installation: diff_gaussian_rasterization 0.0.0
#     Uninstalling diff_gaussian_rasterization-0.0.0:
#       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# ...
# /content/SuGaR/gaussian_splatting/submodules/simple-knn
# Processing /content/SuGaR/gaussian_splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...

# %%
# 1. Install prerequisites required by PyTorch3D
# !pip install fvcore iopath

# 2. Build and install PyTorch3D directly from the Facebook Research repository
# !pip install "git+https://github.com/facebookresearch/pytorch3d.git@stable"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=5a6cf5d4b64c5ae7c601ead44d7059aafbfbe996fc09cc58fbe9db7868abe94c
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=9d439c23e95e9f3feb66dcf4e9fb76803f75a0a9702babd36b6a41b65798ebd0
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git (to revision stable) to /tmp/pip-req-build-u1bq0f9e
# ...

# %%
# %cd /content/SuGaR
# Out:
# /content/SuGaR

# %%
# !python gaussian_splatting/train.py -s /content -m /content/gs_base --iterations 7000
# Out:
# 2026-07-19 15:49:25.495931: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimizing /content/gs_base
# Output folder: /content/gs_base [19/07 15:49:32]
# Reading camera 146/146 [19/07 15:49:32]
# Loading Training Cameras [19/07 15:49:32]
# Loading Test Cameras [19/07 15:49:51]
# Number of points at initialisation :  8746 [19/07 15:49:51]
# Training progress: 100% 7000/7000 [13:36<00:00,  8.57it/s, Loss=0.0173316]
#
# [ITER 7000] Evaluating train: L1 0.013468510285019875 PSNR 34.80695266723633 [19/07 16:03:40]
#
# [ITER 7000] Saving Gaussians [19/07 16:03:40]
#
# Training complete. [19/07 16:03:41]

# %%
# %cd /content/SuGaR
# Out:
# /content/SuGaR

# %%
# !sed -i 's/map_location=nerfmodel.device)/map_location=nerfmodel.device, weights_only=False)/g' /content/SuGaR/sugar_extractors/coarse_mesh.py

# %%
# !python train.py -s /content -c /content/gs_base/ -r "dn_consistency" -t True
# Out:
# Using original 3DGS rasterizer from Inria.
# Will export a UV-textured mesh as an .obj file.
# Will export a ply file with the refined 3D Gaussians at the end of the training.
# Changing sh_levels to match the loaded model: 4
# -----Parsed parameters-----
# Source path: /content
#    > Content: 13
# Gaussian Splatting checkpoint path: /content/gs_base/
#    > Content: 5
# SUGAR checkpoint path: ./output/coarse/content/sugarcoarse_3Dgs7000_densityestim02_sdfnorm02/
# Iteration to load: 7000
# Output directory: ./output/coarse/content
# Depth-Normal consistency factor: 0.05
# SDF estimation factor: 0.2
# SDF better normal factor: 0.2
# Eval split: True
# White background: False
# ---------------------------
# Using device: 0
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# ...

# %%
# !python extract_mesh.py \
  -s /content \
  -c /content/gs_base/ \
  -m ./output/coarse/content/sugarcoarse_3Dgs7000_densityestim02_sdfnorm02/15000.pt
# Out:
# Using original 3DGS rasterizer from Inria.
# -----Parameters-----
# Source path: /content
# Gaussian Splatting Checkpoint path: /content/gs_base/
# Coarse model Checkpoint path: ./output/coarse/content/sugarcoarse_3Dgs7000_densityestim02_sdfnorm02/15000.pt
# Mesh output path: ./output/coarse_mesh/content
# Surface levels:
# [0.1, 0.3, 0.5]
# Decimation targets:
# [200000, 1000000]
# Project mesh on surface points: True
# Use custom bbox: False
# Use eval split: True
# GPU: 0
# Use centers to extract mesh: False
# Use marching cubes: False
# Use vanilla 3DGS: False
# --------------------
# Loading the initial 3DGS model from path /content/gs_base/...
# Found image extension .png
# 127 training images detected.
# The model has been trained for 7000 steps.
#
# Loading the coarse SuGaR model from path
# ./output/coarse/content/sugarcoarse_3Dgs7000_densityestim02_sdfnorm02/15000.pt...
# Use min to initialize scales.
# Initialized radiuses for 3D Gauss Rasterizer
# Coarse model loaded.
# ...
